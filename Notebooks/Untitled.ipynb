# %%
import sys
print(sys.executable)
# Out:
# C:\Users\olivi\Anaconda3\envs\Basemap\python.exe

# %%
from mpl_toolkits.basemap import Basemap

# %%
# %matplotlib inline
import pylab as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
import numpy as np
import ugradio
import astropy.coordinates
import astropy.time
import time
import astropy.io.fits as fits
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-1a54c50d2011> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import ugradio
#       4 import astropy.coordinates
#       5 import astropy.time
#
# ImportError: No module named ugradio

# %%
m = Basemap(projection='ortho',lat_0=90,lon_0=180,rsphere=1.)
lons,lats = m.makegrid(500,500) # 500 lons by 500 lats

plt.figure(figsize=(12,6))

plt.subplot(121)
plt.title('Orthographic (Longitude)')
m.imshow(lons, vmin=-180, vmax=180)
m.drawmapboundary()
m.drawmeridians(lon_lines, labels=[1,1,1,1], labelstyle='+/-')
m.drawparallels(np.arange(-90,90,30)[1:])
plt.colorbar()

plt.subplot(122)
plt.title('Orthographic (Latitude)')
m.imshow(lats, vmax=-90, vmin=90)
m.drawmapboundary()
m.drawmeridians(lon_lines, labels=[1,1,1,1], labelstyle='+/-')
m.drawparallels(np.arange(-90,90,30)[1:])
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-864d11241335> in <module>()
#       8 m.imshow(lons, vmin=-180, vmax=180)
#       9 m.drawmapboundary()
# ---> 10 m.drawmeridians(lon_lines, labels=[1,1,1,1], labelstyle='+/-')
#      11 m.drawparallels(np.arange(-90,90,30)[1:])
#      12 plt.colorbar()
#
# NameError: name 'lon_lines' is not defined

# %%
data_noise_on = []
data_noise_off = []

for i in range(0, 386):
    d_off_avg = []
    d_on_avg = []
    for j in range(1, 21):
        x = '../Data/celestial_pole-noiseoff_' + str(i) + '.fits'
        x.split('_')[-1][:-5] #len(.fits)
        
        d_off = fits.open('../Data/celestial_pole-noiseoff_' + str(i) + '.fits')
        d_off = d_off[j].data['auto0_real']
        d_off_avg.append(d_off)
    d_off_avg = np.mean(d_off_avg, axis=0)
    data_noise_off.append(d_off_avg)
    
#split- chop str into smaller str
    
    for k in range(1, 3):
        d_on = fits.open('../Data/celestial_pole-noiseon_' + str(i) + '.fits')[k].data['auto0_real']
        d_on_avg.append(d_on)
    d_on_avg = np.mean(d_on_avg, axis=0)
    data_noise_on.append(d_on_avg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b66005904b7e> in <module>()
#       9         x.split('_')[-1][:-5] #len(.fits)
#      10
# ---> 11         d_off = fits.open('../Data/celestial_pole-noiseoff_' + str(i) + '.fits')
#      12         d_off = d_off[j].data['auto0_real']
#      13         d_off_avg.append(d_off)
#
# NameError: name 'fits' is not defined
